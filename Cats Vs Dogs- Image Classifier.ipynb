# %% [markdown]
# Cat Dog Classification
# ===

# %%
#importing the packages
import tensorflow as tf
import os
import re
import numpy as np
import zipfile
import matplotlib.pyplot as plt

from tensorflow.contrib import learn
from tensorflow.contrib.learn.python.learn.estimators import model_fn
from tensorflow.contrib.learn import RunConfig as run_config
from keras.callbacks import TensorBoard
slim = tf.contrib.slim

# %% [markdown]
# #### Define some mathematical functions

# %%
# Here 0 means Cat and 1 means Dog
CAT = 0
DOG = 1
#Returns whether the low memory mode is used.
IS_LOW_MEMORY_MODE = True
#current working directory of a process.
cwd = os.getcwd()
#This method is called when RandomState is initialized
np.random.seed(2124)

# %%
#Method to prepare a file
def prepare_file():
  file_list = ['train','test']
  flag = True
  for i in range(len(file_list)):
    filename = file_list[i] + '.zip'
    dest_filename = os.path.join(cwd,'data',filename)
    
    images_path = os.path.join(cwd,'data',file_list[i])    
    zip = zipfile.ZipFile(dest_filename)  
      
  return flag

# %%
#Method to read the image label
def read_image_label_list(folder_dir):
    dir_list = os.listdir(os.path.join(cwd,folder_dir))    
    filenames = []
    labels = []
    
    for i, d in enumerate(dir_list):
        if re.search("train",folder_dir):
            if re.search("cat", d):
                labels.append(CAT)
            else:
                labels.append(DOG)
        else:
            labels.append(-1)
        filenames.append(os.path.join(cwd, folder_dir, d))    
    return filenames, labels

# %%
#Method to read the image from disk
def read_images_from_disk(input_queue):
    filename = input_queue[0]
    label = input_queue[1]
    
    file_contents = tf.read_file(filename)
    image = tf.image.decode_image(file_contents, channels=3)
    image.set_shape([None, None, 3])
    
    return image, label

# %%
#Method to generate input function
def gen_input_fn(image_list, label_list, batch_size, shuffle):
    
    def input_fn():
        images = tf.convert_to_tensor(image_list, dtype=tf.string)
        labels = tf.convert_to_tensor(label_list, dtype=tf.int32)

        input_queue = tf.train.slice_input_producer(
            [images, labels],
            capacity=batch_size * 5,
            shuffle=shuffle,
            name="file_input_queue"
        )

        image, label = read_images_from_disk(input_queue)
        image = tf.image.resize_images(image, (224, 224), tf.image.ResizeMethod.NEAREST_NEIGHBOR)

        image_batch, label_batch = tf.train.batch(
            [image, label],
            batch_size=batch_size,
            num_threads=1,
            name="batch_queue",
            capacity=batch_size * 10,
            allow_smaller_final_batch = False
        )
        
        return (
            tf.identity(image_batch, name="features"), 
            tf.identity(label_batch, name="label")
        )

    return input_fn

# %%
#Method to train a valid input function
def train_valid_input_fn(data_dir, train_batch_size, valid_batch_size=None):
    img, labels = read_image_label_list(data_dir)
    img = np.array(img)
    labels = np.array(labels)
    data_size = img.shape[0]

    print("Data size: " + str(data_size))
    split = int(0.7 * data_size)

    random_seq = np.random.permutation(data_size)

    img = img[random_seq]
    labels = labels[random_seq]
    
    if valid_batch_size == None:
        valid_batch_size = train_batch_size

    return (
        gen_input_fn(img[0:split], labels[0:split], train_batch_size, shuffle = True),
        gen_input_fn(img[split:], labels[split:], valid_batch_size, shuffle = False)
           )

# %%
#Method to test input function
def test_input_fn(data_dir,batch_size):
    image_list, label_list = read_image_label_list(data_dir)
    return gen_input_fn(image_list, label_list, batch_size, shuffle = False), image_list

# %% [markdown]
# ### Data visualize

# %%
if prepare_file():
    print("Files completed!")
# Out:
# Files completed!

# %%
#Method to plot data
def plot_img(data, label=None):
    plt.ion()
    plt.figure()
    plt.imshow(data)
    if label is not None:
        plt.title(label)

# %%
#Method to preview data
def preview_img():
    
    img_preview = tf.Graph()
    
    with img_preview.as_default():
        tensor_train, _ = train_valid_input_fn('data/train', 5)
        result = tf.tuple(tensor_train())
        
    with tf.Session(graph=img_preview) as sess:
        sess.run(tf.global_variables_initializer())
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord)

        images, labels = sess.run(result)
        for i in range(len(images)):
            plot_img(images[i], str(labels[i]))

        coord.request_stop()
        coord.join(threads)

        sess.close()

preview_img()
# Out:
# Data size: 25000

# %% [markdown]
# ### Define Model

# %%
#Cat-Dog Method Declaration
def catdog_model(inputs, is_training):
    with tf.variable_scope('catdog', values=[inputs]):
        with slim.arg_scope(
            [slim.conv2d, slim.fully_connected],
            activation_fn=tf.nn.relu6,
            weights_initializer=tf.truncated_normal_initializer(0.0, 0.01)):
            
            net = inputs
        
            if IS_LOW_MEMORY_MODE == False:
                net = slim.repeat(net, 2, slim.conv2d, 64, [3, 3], scope='conv1')
                net = slim.max_pool2d(net, [2, 2], scope='pool1')

                net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2')
                net = slim.max_pool2d(net, [2, 2], scope='pool2')

                net = slim.repeat(net, 4, slim.conv2d, 256, [3, 3], scope='conv3')
                net = slim.max_pool2d(net, [2, 2], scope='pool3')
                net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv4')
                net = slim.max_pool2d(net, [2, 2], scope='pool4')
                net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv5')
                net = slim.max_pool2d(net, [2, 2], scope='pool5')

                net = tf.reshape(net, [-1, 7 * 7 * 512])

                net = slim.fully_connected(net, 2048, scope='fc6')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout6')

                net = slim.fully_connected(net, 2048, scope='fc7')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout7')

                net = slim.fully_connected(net, 2, activation_fn=None, scope='fc8')
                
            else:
                # Model for my Mac T_T
                net = tf.image.resize_images(net, (72, 72), tf.image.ResizeMethod.NEAREST_NEIGHBOR)
                
                net = slim.repeat(net, 1, slim.conv2d, 64, [3, 3], scope='conv1')
                net = slim.max_pool2d(net, [2, 2], scope='pool1')
                
                net = slim.repeat(net, 1, slim.conv2d, 128, [3, 3], scope='conv2')
                net = slim.max_pool2d(net, [2, 2], scope='pool2')
                
                net = slim.repeat(net, 2, slim.conv2d, 256, [3, 3], scope='conv3')
                net = slim.max_pool2d(net, [2, 2], scope='pool3')
                
                net = tf.reshape(net, [-1, 9 * 9 * 256])
                
                net = slim.fully_connected(net, 1024, scope='fc4')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout4')

                net = slim.fully_connected(net, 1024, scope='fc5')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout5')

                net = slim.fully_connected(net, 2, activation_fn=None, scope='fc6')
            
            return net

# %%
#Cat-Dog Model function
def catdog_model_fn(features, labels, mode, params):
    
    is_training = False
    if mode == learn.ModeKeys.TRAIN:
        is_training = True
        
    output = catdog_model(features, is_training)
    
    log_loss = None
    train_op = None
    eval_metric_ops = None
    
    softmax_predictions = tf.nn.softmax(output)
    
    if mode != learn.ModeKeys.INFER:
        onehot_labels = tf.one_hot(
            tf.cast(labels, tf.int32), 
            depth = 2
        )
        log_loss = tf.identity(
            tf.losses.log_loss(
                onehot_labels,
                tf.nn.softmax(output),
                reduction = tf.losses.Reduction.MEAN
            ),
            name = "log_loss_tensor"
        )
        eval_metric_ops = {
            "log_loss": log_loss
        }
        
    if mode == learn.ModeKeys.TRAIN:
        train_op = tf.contrib.layers.optimize_loss(
            loss = log_loss,
            global_step = tf.contrib.framework.get_global_step(),
            learning_rate = params['learning_rate'],
            optimizer = "Adam"
        )
        
    predictions = {
        'predict': softmax_predictions
    }
    
    return model_fn.ModelFnOps(
        mode = mode,
        predictions = predictions,
        loss = log_loss,
        train_op = train_op,
        eval_metric_ops = eval_metric_ops
    )

# %%
#Feature Engineering function
def feature_engineering_fn(features, labels):
    features = tf.to_float(features)
    features = tf.map_fn(tf.image.per_image_standardization, features)
    return features, labels

tf.logging.set_verbosity(tf.logging.ERROR)

model_path = 'model' if IS_LOW_MEMORY_MODE else 'model'
classifier = learn.Estimator(
    model_fn = catdog_model_fn, 
    model_dir = model_path,
    config = run_config(
        save_summary_steps = 10,
        keep_checkpoint_max = 3,
        save_checkpoints_steps = 75
    ),
    feature_engineering_fn = feature_engineering_fn,
    params = {
        'learning_rate': 0.01
    }
)

train_input_fn, validate_input_fn = train_valid_input_fn('data/train', 32, 64)

logging_hook = tf.train.LoggingTensorHook(
    tensors = {
        'log_loss': 'log_loss_tensor'
    }, 
    every_n_iter = 3
)

validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    input_fn = validate_input_fn,
    eval_steps = 30,
    every_n_steps = 100,
    name = 'Validatation'
)
# Out:
# Data size: 25000

# %% [markdown]
# #### Train the Model

# %%
tf.logging.set_verbosity(tf.logging.INFO)
classifier.fit(
    input_fn = train_input_fn,
    steps = 100,
    monitors = [logging_hook, validation_monitor]
)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from model/model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into model/model.ckpt.
# INFO:tensorflow:log_loss = 6.5479765
# INFO:tensorflow:Starting evaluation at 2018-02-06-15:59:45
# INFO:tensorflow:Restoring parameters from model/model.ckpt-201
# INFO:tensorflow:Evaluation [1/30]
# INFO:tensorflow:Evaluation [2/30]
# INFO:tensorflow:Evaluation [3/30]
# INFO:tensorflow:Evaluation [4/30]
# INFO:tensorflow:Evaluation [5/30]
# INFO:tensorflow:Evaluation [6/30]
# INFO:tensorflow:Evaluation [7/30]
# INFO:tensorflow:Evaluation [8/30]
# INFO:tensorflow:Evaluation [9/30]
# INFO:tensorflow:Evaluation [10/30]
# INFO:tensorflow:Evaluation [11/30]
# INFO:tensorflow:Evaluation [12/30]
# INFO:tensorflow:Evaluation [13/30]
# INFO:tensorflow:Evaluation [14/30]
# INFO:tensorflow:Evaluation [15/30]
# INFO:tensorflow:Evaluation [16/30]
# INFO:tensorflow:Evaluation [17/30]
# INFO:tensorflow:Evaluation [18/30]
# INFO:tensorflow:Evaluation [19/30]
# INFO:tensorflow:Evaluation [20/30]
# INFO:tensorflow:Evaluation [21/30]
# INFO:tensorflow:Evaluation [22/30]
# INFO:tensorflow:Evaluation [23/30]
# INFO:tensorflow:Evaluation [24/30]
# INFO:tensorflow:Evaluation [25/30]
# INFO:tensorflow:Evaluation [26/30]
# INFO:tensorflow:Evaluation [27/30]
# INFO:tensorflow:Evaluation [28/30]
# INFO:tensorflow:Evaluation [29/30]
# INFO:tensorflow:Evaluation [30/30]
# INFO:tensorflow:Finished evaluation at 2018-02-06-16:01:05
# INFO:tensorflow:Saving dict for global step 201: global_step = 201, log_loss = 7.555359, loss = 8.210157
# INFO:tensorflow:Validation (step 201): log_loss = 7.555359, loss = 8.210157, global_step = 201
# INFO:tensorflow:loss = 6.5479765, step = 201
# INFO:tensorflow:log_loss = 7.555357 (92.375 sec)
# INFO:tensorflow:log_loss = 8.059048 (11.834 sec)
# INFO:tensorflow:log_loss = 8.562738 (11.838 sec)
# INFO:tensorflow:log_loss = 9.57012 (11.902 sec)
# INFO:tensorflow:log_loss = 8.562738 (12.013 sec)
# INFO:tensorflow:log_loss = 8.059048 (12.696 sec)
# INFO:tensorflow:log_loss = 7.0516667 (11.472 sec)
# INFO:tensorflow:log_loss = 7.5553575 (12.741 sec)
# INFO:tensorflow:log_loss = 10.073811 (12.404 sec)
# INFO:tensorflow:log_loss = 9.066429 (11.569 sec)
# INFO:tensorflow:log_loss = 6.044286 (12.372 sec)
# INFO:tensorflow:log_loss = 7.0516667 (12.370 sec)
# INFO:tensorflow:log_loss = 10.577501 (12.698 sec)
# INFO:tensorflow:log_loss = 9.066429 (12.242 sec)
# INFO:tensorflow:log_loss = 9.066429 (12.526 sec)
# INFO:tensorflow:log_loss = 5.036905 (13.085 sec)
# INFO:tensorflow:log_loss = 8.562738 (11.796 sec)
# INFO:tensorflow:log_loss = 8.562738 (11.581 sec)
# INFO:tensorflow:log_loss = 10.073811 (11.901 sec)
# INFO:tensorflow:log_loss = 10.073811 (11.899 sec)
# INFO:tensorflow:log_loss = 9.066429 (12.681 sec)
# INFO:tensorflow:log_loss = 11.081192 (12.459 sec)
# INFO:tensorflow:log_loss = 9.066429 (12.285 sec)
# INFO:tensorflow:log_loss = 7.051667 (12.054 sec)
# INFO:tensorflow:Saving checkpoints for 276 into model/model.ckpt.
# INFO:tensorflow:log_loss = 8.562738 (15.835 sec)
# INFO:tensorflow:log_loss = 8.562738 (13.310 sec)
# INFO:tensorflow:log_loss = 6.5479765 (13.815 sec)
# INFO:tensorflow:log_loss = 8.562738 (12.364 sec)
# INFO:tensorflow:log_loss = 8.562738 (12.084 sec)
# INFO:tensorflow:log_loss = 8.562738 (12.810 sec)
# INFO:tensorflow:log_loss = 5.036905 (13.451 sec)
# INFO:tensorflow:log_loss = 7.555357 (12.162 sec)
# INFO:tensorflow:log_loss = 7.555357 (12.331 sec)
# INFO:tensorflow:Saving checkpoints for 300 into model/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.555357.
# Estimator(params={'learning_rate': 0.01})

# %%
#Model Evaluation
classifier.evaluate(
    input_fn = validate_input_fn,
    steps = 75
)
# Out:
# INFO:tensorflow:Starting evaluation at 2018-02-06-16:08:01
# INFO:tensorflow:Restoring parameters from model/model.ckpt-300
# INFO:tensorflow:Evaluation [1/75]
# INFO:tensorflow:Evaluation [2/75]
# INFO:tensorflow:Evaluation [3/75]
# INFO:tensorflow:Evaluation [4/75]
# INFO:tensorflow:Evaluation [5/75]
# INFO:tensorflow:Evaluation [6/75]
# INFO:tensorflow:Evaluation [7/75]
# INFO:tensorflow:Evaluation [8/75]
# INFO:tensorflow:Evaluation [9/75]
# INFO:tensorflow:Evaluation [10/75]
# INFO:tensorflow:Evaluation [11/75]
# INFO:tensorflow:Evaluation [12/75]
# INFO:tensorflow:Evaluation [13/75]
# INFO:tensorflow:Evaluation [14/75]
# INFO:tensorflow:Evaluation [15/75]
# INFO:tensorflow:Evaluation [16/75]
# INFO:tensorflow:Evaluation [17/75]
# INFO:tensorflow:Evaluation [18/75]
# INFO:tensorflow:Evaluation [19/75]
# INFO:tensorflow:Evaluation [20/75]
# INFO:tensorflow:Evaluation [21/75]
# INFO:tensorflow:Evaluation [22/75]
# INFO:tensorflow:Evaluation [23/75]
# INFO:tensorflow:Evaluation [24/75]
# INFO:tensorflow:Evaluation [25/75]
# INFO:tensorflow:Evaluation [26/75]
# INFO:tensorflow:Evaluation [27/75]
# INFO:tensorflow:Evaluation [28/75]
# INFO:tensorflow:Evaluation [29/75]
# INFO:tensorflow:Evaluation [30/75]
# INFO:tensorflow:Evaluation [31/75]
# INFO:tensorflow:Evaluation [32/75]
# INFO:tensorflow:Evaluation [33/75]
# INFO:tensorflow:Evaluation [34/75]
# INFO:tensorflow:Evaluation [35/75]
# INFO:tensorflow:Evaluation [36/75]
# INFO:tensorflow:Evaluation [37/75]
# INFO:tensorflow:Evaluation [38/75]
# INFO:tensorflow:Evaluation [39/75]
# INFO:tensorflow:Evaluation [40/75]
# INFO:tensorflow:Evaluation [41/75]
# INFO:tensorflow:Evaluation [42/75]
# INFO:tensorflow:Evaluation [43/75]
# INFO:tensorflow:Evaluation [44/75]
# INFO:tensorflow:Evaluation [45/75]
# INFO:tensorflow:Evaluation [46/75]
# INFO:tensorflow:Evaluation [47/75]
# INFO:tensorflow:Evaluation [48/75]
# INFO:tensorflow:Evaluation [49/75]
# INFO:tensorflow:Evaluation [50/75]
# INFO:tensorflow:Evaluation [51/75]
# INFO:tensorflow:Evaluation [52/75]
# INFO:tensorflow:Evaluation [53/75]
# INFO:tensorflow:Evaluation [54/75]
# INFO:tensorflow:Evaluation [55/75]
# INFO:tensorflow:Evaluation [56/75]
# INFO:tensorflow:Evaluation [57/75]
# INFO:tensorflow:Evaluation [58/75]
# INFO:tensorflow:Evaluation [59/75]
# INFO:tensorflow:Evaluation [60/75]
# INFO:tensorflow:Evaluation [61/75]
# INFO:tensorflow:Evaluation [62/75]
# INFO:tensorflow:Evaluation [63/75]
# INFO:tensorflow:Evaluation [64/75]
# INFO:tensorflow:Evaluation [65/75]
# INFO:tensorflow:Evaluation [66/75]
# INFO:tensorflow:Evaluation [67/75]
# INFO:tensorflow:Evaluation [68/75]
# INFO:tensorflow:Evaluation [69/75]
# INFO:tensorflow:Evaluation [70/75]
# INFO:tensorflow:Evaluation [71/75]
# INFO:tensorflow:Evaluation [72/75]
# INFO:tensorflow:Evaluation [73/75]
# INFO:tensorflow:Evaluation [74/75]
# INFO:tensorflow:Evaluation [75/75]
# INFO:tensorflow:Finished evaluation at 2018-02-06-16:11:15
# INFO:tensorflow:Saving dict for global step 300: global_step = 300, log_loss = 9.066431, loss = 8.163145
# {'global_step': 300, 'log_loss': 9.066431, 'loss': 8.163145}

# %% [markdown]
# #### Final Prediction

# %%
#Print the result
test_fn, image_test_list = test_input_fn('data/test',32)
test_n = len(image_test_list)

print("Test size: %d" % test_n)

result_file = open(os.path.join(cwd, 'result/result.txt'),'w+')
result_file.write('id,label\n')

predictions = classifier.predict(input_fn = test_fn, as_iterable=True)
for i, p in enumerate(predictions):
    if i >= test_n:
        break
        
    id = image_test_list[i].split("/")[-1]
    id = id.split(".")[0]

    if i % 100 == 0:
        print("Predict %d %s: %f" % (i,image_test_list[i],p["predict"][1]))

    result_file.write("%s,%f\n" % (id, p["predict"][1]))

result_file.flush()
result_file.close()
print('Finish!!')
# Out:
# Test size: 12500
# INFO:tensorflow:Restoring parameters from model/model.ckpt-300
# Predict 0 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/361.jpg: 1.000000
# Predict 100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7579.jpg: 1.000000
# Predict 200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2517.jpg: 1.000000
# Predict 300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/84.jpg: 1.000000
# Predict 400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1895.jpg: 1.000000
# Predict 500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4914.jpg: 1.000000
# Predict 600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9553.jpg: 1.000000
# Predict 700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4363.jpg: 1.000000
# Predict 800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10603.jpg: 1.000000
# Predict 900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8116.jpg: 1.000000
# Predict 1000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2679.jpg: 1.000000
# Predict 1100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1503.jpg: 1.000000
# Predict 1200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4862.jpg: 1.000000
# Predict 1300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2896.jpg: 1.000000
# Predict 1400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/716.jpg: 1.000000
# Predict 1500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1924.jpg: 1.000000
# Predict 1600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7924.jpg: 1.000000
# Predict 1700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3950.jpg: 1.000000
# Predict 1800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10145.jpg: 1.000000
# Predict 1900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2682.jpg: 1.000000
# Predict 2000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2484.jpg: 1.000000
# Predict 2100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7626.jpg: 1.000000
# Predict 2200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8167.jpg: 1.000000
# Predict 2300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/593.jpg: 1.000000
# Predict 2400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4333.jpg: 1.000000
# Predict 2500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2482.jpg: 1.000000
# Predict 2600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9988.jpg: 1.000000
# Predict 2700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6872.jpg: 1.000000
# Predict 2800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8585.jpg: 1.000000
# Predict 2900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12411.jpg: 1.000000
# Predict 3000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12079.jpg: 1.000000
# Predict 3100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/962.jpg: 1.000000
# Predict 3200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9228.jpg: 1.000000
# Predict 3300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11431.jpg: 1.000000
# Predict 3400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7184.jpg: 1.000000
# Predict 3500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11039.jpg: 1.000000
# Predict 3600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2901.jpg: 1.000000
# Predict 3700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10565.jpg: 1.000000
# Predict 3800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2224.jpg: 1.000000
# Predict 3900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5028.jpg: 1.000000
# Predict 4000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2124.jpg: 1.000000
# Predict 4100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9719.jpg: 1.000000
# Predict 4200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12033.jpg: 1.000000
# Predict 4300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7293.jpg: 1.000000
# Predict 4400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6962.jpg: 1.000000
# Predict 4500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9367.jpg: 1.000000
# Predict 4600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7635.jpg: 1.000000
# Predict 4700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12069.jpg: 1.000000
# Predict 4800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1783.jpg: 1.000000
# Predict 4900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12296.jpg: 1.000000
# Predict 5000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7269.jpg: 1.000000
# Predict 5100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11796.jpg: 1.000000
# Predict 5200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/893.jpg: 1.000000
# Predict 5300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7502.jpg: 1.000000
# Predict 5400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4445.jpg: 1.000000
# Predict 5500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7530.jpg: 1.000000
# Predict 5600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12085.jpg: 1.000000
# Predict 5700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2422.jpg: 1.000000
# Predict 5800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11974.jpg: 1.000000
# Predict 5900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7594.jpg: 1.000000
# Predict 6000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1350.jpg: 1.000000
# Predict 6100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6824.jpg: 1.000000
# Predict 6200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7107.jpg: 1.000000
# Predict 6300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6655.jpg: 1.000000
# Predict 6400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11125.jpg: 1.000000
# Predict 6500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6968.jpg: 1.000000
# Predict 6600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8189.jpg: 1.000000
# Predict 6700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5140.jpg: 1.000000
# Predict 6800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4766.jpg: 1.000000
# Predict 6900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2506.jpg: 1.000000
# Predict 7000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3684.jpg: 1.000000
# Predict 7100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10629.jpg: 1.000000
# Predict 7200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9879.jpg: 1.000000
# Predict 7300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/890.jpg: 1.000000
# Predict 7400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12389.jpg: 1.000000
# Predict 7500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5859.jpg: 1.000000
# Predict 7600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6550.jpg: 1.000000
# Predict 7700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6215.jpg: 1.000000
# Predict 7800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7618.jpg: 1.000000
# Predict 7900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/511.jpg: 1.000000
# Predict 8000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/6472.jpg: 1.000000
# Predict 8100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11195.jpg: 1.000000
# Predict 8200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5623.jpg: 1.000000
# Predict 8300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1978.jpg: 1.000000
# Predict 8400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1456.jpg: 1.000000
# Predict 8500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2601.jpg: 1.000000
# Predict 8600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/12244.jpg: 1.000000
# Predict 8700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/888.jpg: 1.000000
# Predict 8800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5916.jpg: 1.000000
# Predict 8900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10208.jpg: 1.000000
# Predict 9000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8484.jpg: 1.000000
# Predict 9100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11687.jpg: 1.000000
# Predict 9200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10873.jpg: 1.000000
# Predict 9300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/87.jpg: 1.000000
# Predict 9400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3320.jpg: 1.000000
# Predict 9500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/839.jpg: 1.000000
# Predict 9600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2543.jpg: 1.000000
# Predict 9700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7564.jpg: 1.000000
# Predict 9800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8602.jpg: 1.000000
# Predict 9900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8200.jpg: 1.000000
# Predict 10000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11672.jpg: 1.000000
# Predict 10100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5730.jpg: 1.000000
# Predict 10200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4216.jpg: 1.000000
# Predict 10300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9967.jpg: 1.000000
# Predict 10400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/219.jpg: 1.000000
# Predict 10500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2229.jpg: 1.000000
# Predict 10600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2603.jpg: 1.000000
# Predict 10700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8464.jpg: 1.000000
# Predict 10800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3979.jpg: 1.000000
# Predict 10900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/1107.jpg: 1.000000
# Predict 11000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5010.jpg: 1.000000
# Predict 11100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/43.jpg: 1.000000
# Predict 11200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/5405.jpg: 1.000000
# Predict 11300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/9062.jpg: 1.000000
# Predict 11400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/10718.jpg: 1.000000
# Predict 11500 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/11573.jpg: 1.000000
# Predict 11600 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3916.jpg: 1.000000
# Predict 11700 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/8079.jpg: 1.000000
# Predict 11800 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4562.jpg: 1.000000
# Predict 11900 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/46.jpg: 1.000000
# Predict 12000 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7730.jpg: 1.000000
# Predict 12100 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/4075.jpg: 1.000000
# Predict 12200 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/2172.jpg: 1.000000
# Predict 12300 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/3826.jpg: 1.000000
# Predict 12400 /home/kunal/Documents/Data_Science_Practice/cat-vs-dog-classification-master/src/Graph/data/test/7778.jpg: 1.000000
# Finish!!
